# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# from sklearn.datasets import fetch_california_housing
# data = fetch_california_housing()

# %%
df = pd.read_excel('fetch_california_housing.xlsx')

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  target
# 0        -122.23   4.526
# 1        -122.22   3.585
# 2        -122.24   3.521
# 3        -122.25   3.413
# 4        -122.25   3.422
# ...          ...     ...
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894
#
# [20640 rows x 9 columns]

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1  8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2  7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3  5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4  3.8462        52  6.281853   1.081081         565  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  target
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894

# %%
df['Price'] = df['target']

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  target  Price
# 0        -122.23   4.526  4.526
# 1        -122.22   3.585  3.585
# 2        -122.24   3.521  3.521
# 3        -122.25   3.413  3.413
# 4        -122.25   3.422  3.422
# ...          ...     ...    ...
# 20635    -121.09   0.781  0.781
# 20636    -121.21   0.771  0.771
# 20637    -121.22   0.923  0.923
# 20638    -121.32   0.847  0.847
# 20639    -121.24   0.894  0.894
#
# [20640 rows x 10 columns]

# %%
df.drop('target', axis = 1, inplace= True)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
#multicollinearity >> when one feature is explained by all other features(more than 2)
#when two features>> correlation
#when more than two features>> multicollinearity>> clustermap, VIF

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# Population -0.108785   0.099773 -0.024650
# AveOccup    0.002366   0.002476 -0.023737
# Latitude    1.000000  -0.924664 -0.144160
# Longitude  -0.924664   1.000000 -0.045967
# Price      -0.144160  -0.045967  1.000000

# %%
sns.heatmap(df.corr(), annot= True, vmin= -1, vmax= 1)
# Out:
# <Axes: >

# %%
# clustermap table shows group(cluster) relationship

plt.figure(figsize=(4,5))
sns.clustermap(df.corr(), vmin= -1, vmax= 1, annot= True)
plt.show()

# %%
# problem with the above plot interpretation >> you understand the relationship among features together
# but don't understand how much >> lack of quantitative measure, so we study vif

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["Feature"] = df.columns

# %%
vif
# Out:
#       Feature
# 0      MedInc
# 1    HouseAge
# 2    AveRooms
# 3   AveBedrms
# 4  Population
# 5    AveOccup
# 6    Latitude
# 7   Longitude
# 8       Price

# %%
vif["VIF"] = [variance_inflation_factor(df.values, i) for i in range(len(df.columns))]

# %%
vif
# Out:
#       Feature         VIF
# 0      MedInc   19.624998
# 1    HouseAge    7.592663
# 2    AveRooms   47.956351
# 3   AveBedrms   45.358192
# 4  Population    2.936078
# 5    AveOccup    1.099530
# 6    Latitude  568.497332
# 7   Longitude  640.064211
# 8       Price    9.285659

# %%
#if vif > 10, drop the features one by one>> here highest is Longitude, we will drop this and then again
#calculate vif and then again drop the highest one

df1 = df.copy()

# %%
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df1.drop('Longitude', axis=1, inplace=True)

# %%
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Price
# 0      4.526
# 1      3.585
# 2      3.521
# 3      3.413
# 4      3.422
# ...      ...
# 20635  0.781
# 20636  0.771
# 20637  0.923
# 20638  0.847
# 20639  0.894
#
# [20640 rows x 8 columns]

# %%
df1.drop('AveRooms', axis=1, inplace=True)

vif = pd.DataFrame()
vif["Feature"] = df1.columns
vif["VIF"] = [variance_inflation_factor(df1.values, i) for i in range(len(df1.columns))]
vif
# Out:
#       Feature        VIF
# 0      MedInc  10.584081
# 1    HouseAge   7.260588
# 2   AveBedrms   6.440667
# 3  Population   2.762794
# 4    AveOccup   1.098719
# 5    Latitude  22.094483
# 6       Price   8.674858

# %%
df1.drop('Latitude', axis=1, inplace=True)

vif = pd.DataFrame()
vif["Feature"] = df1.columns
vif["VIF"] = [variance_inflation_factor(df1.values, i) for i in range(len(df1.columns))]
vif
# Out:
#       Feature       VIF
# 0      MedInc  8.855104
# 1    HouseAge  4.156145
# 2   AveBedrms  4.264253
# 3  Population  2.223926
# 4    AveOccup  1.098671
# 5       Price  8.607339

# %%
# now all the features vif is below 10, so we can build the model

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df1
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup  Price
# 0      8.3252        41   1.023810         322  2.555556  4.526
# 1      8.3014        21   0.971880        2401  2.109842  3.585
# 2      7.2574        52   1.073446         496  2.802260  3.521
# 3      5.6431        52   1.073059         558  2.547945  3.413
# 4      3.8462        52   1.081081         565  2.181467  3.422
# ...       ...       ...        ...         ...       ...    ...
# 20635  1.5603        25   1.133333         845  2.560606  0.781
# 20636  2.5568        18   1.315789         356  3.122807  0.771
# 20637  1.7000        17   1.120092        1007  2.325635  0.923
# 20638  1.8672        18   1.171920         741  2.123209  0.847
# 20639  2.3886        16   1.162264        1387  2.616981  0.894
#
# [20640 rows x 6 columns]

# %%
x = df1.iloc[:, :-1]  # independent variable
y = df1.iloc[:, -1]   # target variable

# %%
x
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup
# 0      8.3252        41   1.023810         322  2.555556
# 1      8.3014        21   0.971880        2401  2.109842
# 2      7.2574        52   1.073446         496  2.802260
# 3      5.6431        52   1.073059         558  2.547945
# 4      3.8462        52   1.081081         565  2.181467
# ...       ...       ...        ...         ...       ...
# 20635  1.5603        25   1.133333         845  2.560606
# 20636  2.5568        18   1.315789         356  3.122807
# 20637  1.7000        17   1.120092        1007  2.325635
# 20638  1.8672        18   1.171920         741  2.123209
# 20639  2.3886        16   1.162264        1387  2.616981
#
# [20640 rows x 5 columns]

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.30, random_state= 1)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup
# 5748   2.9148        15   1.105532        3164  2.692766
# 5592   3.1779        41   1.054825        1658  3.635965
# 2110   2.5111        49   0.964361        1290  2.704403
# 13901  2.5405        15   1.422326        2568  2.388837
# 18425  4.5033         7   1.101173        1739  2.549853
# ...       ...       ...        ...         ...       ...
# 10955  1.7823        17   1.087156        1079  2.474771
# 17289  8.5608        42   1.011538         753  2.896154
# 5192   1.1326        42   1.006826         775  2.645051
# 12172  2.6322        10   0.951782        1323  2.773585
# 235    2.3036        35   1.176923        1009  2.587179
#
# [14448 rows x 5 columns]

# %%
x_test
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup
# 4712   3.2500        39   1.073718        1109  1.777244
# 2151   1.9784        37   1.038813        1143  2.609589
# 15927  4.0132        46   1.012315        1534  3.778325
# 82     1.5208        52   1.114943         200  2.298851
# 8161   5.1795        37   1.024735         711  2.512367
# ...       ...       ...        ...         ...       ...
# 11387  4.2159        18   1.144444         436  2.422222
# 2523   3.6429        33   1.149254         190  2.835821
# 18897  2.5865        47   1.041958         794  2.776224
# 18878  2.6098        13   1.104533        2957  2.735430
# 4287   1.7083        29   1.164395        3432  2.923339
#
# [6192 rows x 5 columns]

# %%
y_train
# Out:
# 5748     2.38700
# 5592     1.71100
# 2110     0.55400
# 13901    0.69600
# 18425    2.13100
#           ...
# 10955    2.05300
# 17289    5.00001
# 5192     1.04800
# 12172    1.40700
# 235      1.26000
# Name: Price, Length: 14448, dtype: float64

# %%
y_test
# Out:
# 4712     3.550
# 2151     0.707
# 15927    2.294
# 82       1.125
# 8161     2.254
#          ...
# 11387    2.113
# 2523     0.875
# 18897    1.098
# 18878    1.625
# 4287     1.667
# Name: Price, Length: 6192, dtype: float64

# %%
# Scaling(optional) jcan be done after train test split

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.50715954, -1.07853296,  0.01547783,  1.53466411, -0.03473461],
#        [-0.36780162,  0.98848922, -0.08556377,  0.20264384,  0.04136812],
#        [-0.72098999,  1.62449604, -0.26582609, -0.12284318, -0.03379571],
#        ...,
#        [-1.45114921,  1.06799007, -0.18120784, -0.57834812, -0.03858451],
#        [-0.65684615, -1.47603722, -0.29089077, -0.09365549, -0.02821367],
#        [-0.83089789,  0.5114841 ,  0.15773486, -0.37138083, -0.04325394]])

# %%
x_test
# Out:
# array([[-0.32961194,  0.82948751, -0.04791601, -0.28293327, -0.10860423],
#        [-1.00314873,  0.67048581, -0.11746951, -0.2528611 , -0.0414458 ],
#        [ 0.07463726,  1.38599348, -0.17026957,  0.09296887,  0.05285456],
#        ...,
#        [-0.68105238,  1.46549433, -0.11120214, -0.56154308, -0.02800075],
#        [-0.66871091, -1.23753466,  0.01348703,  1.35157766, -0.03129222],
#        [-1.14621438,  0.03447898,  0.13277135,  1.77170358, -0.01613065]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.8295202 ,  0.23888438,  0.02058888,  0.03902186, -0.05185743])

# %%
model.intercept_
# Out:
# np.float64(2.0765314825581394)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1.99486815, 1.39443153, 2.46691805, ..., 1.83891855, 1.28083607,
#        1.20666527])

# %%
# performance metrics

from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(np.sqrt(mean_squared_error(y_test, y_pred)))
print(r2_score(y_test, y_pred))
# Out:
# 0.6046846522578226
# 0.6544937093127863
# 0.809007854914145
# 0.502166171877851

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.502166171877851

# %%
# adjusted rsquare

1 - ((1 - score) * len(y_test)-1) / (len(y_test) - x_test.shape[1]-1)
# Out:
# 0.5018449622159155

# %%
# here number of features were low, thats why you droped the features one by one and checked each time
# what if the no. of feature is 1000 in number
# implementation using RFE(Recursive feature elimination)

# %%
x = df.iloc[:, :-1] # iv
y = df.iloc[:, 1]   # dv

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
y
# Out:
# 0        41
# 1        21
# 2        52
# 3        52
# 4        52
#          ..
# 20635    25
# 20636    18
# 20637    17
# 20638    18
# 20639    16
# Name: HouseAge, Length: 20640, dtype: int64

# %%
x.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25, random_state= 1)

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(LinearRegression(), n_features_to_select= 5)
rfe
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
rfe.fit(x_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
rfe.support_
# Out:
# array([ True,  True,  True,  True, False, False, False,  True])

# %%
x.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
rfe.ranking_
# Out:
# array([1, 1, 1, 1, 3, 2, 4, 1])

# %%
y_pred = rfe.predict(x_test)  #since the train test split is not done

# %%
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(np.sqrt(mean_squared_error(y_test, y_pred)))
print(r2_score(y_test, y_pred))
# Out:
# 2.5349231757604154e-15
# 1.6402650267842554e-29
# 4.050018551543012e-15
# 1.0

# %%
# adjusted rsquare

1 - ((1 - score) * len(y_test)-1) / (len(y_test) - x_test.shape[1]-1)
# Out:
# 0.5014904769733471
