# %%
#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

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %%
# !ls "/content/drive"
# Out:
# MyDrive

# %%
cd /content/drive/MyDrive/Skills/Machine-Learning/
# Out:
# /content/drive/MyDrive/Skills/Machine-Learning

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Skills/Machine-Learning

# %%
# %cd "/content/drive/MyDrive/Skills/Machine-Learning"
# !git init
# Out:
# /content/drive/MyDrive/Skills/Machine-Learning
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Skills/Machine-Learning/.git/

# %%
# !git remote set-url origin https://ydv-prince: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@github.com/ydv-prince/Machine-Learning.git

# %%
# !git remote -v
# Out:
# origin	https://ydv-prince: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@github.com/ydv-prince/Machine-Learning.git (fetch)
# origin	https://ydv-prince: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@github.com/ydv-prince/Machine-Learning.git (push)

# %%
# !git branch -M main

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add Linear_Regression

# %%
# !git config --global user.email "psychoaimerhere@gmail.com"
# !git config --global user.name "ydv-prince"

# %%
# !git commit -m "Structured folder for Linear Regression"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/ydv-prince/Machine-Learning
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push -u origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push -u origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
# !git branch structured

# %%
# !git checkout structured
# Out:
# Switched to branch 'structured'

# %%
# !git push -u origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because a pushed branch tip is behind its remote
# hint: counterpart. Check out this branch and integrate the remote changes
# hint: (e.g. 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git checkout main
# Out:
# Switched to branch 'main'

# %%
# !git branch -d structured
# Out:
# Deleted branch structured (was 7d49292).

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/ydv-prince/Machine-Learning
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/ydv-prince/Machine-Learning
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git push origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull --no-rebase origin main
# Out:
# From https://github.com/ydv-prince/Machine-Learning
#  * branch            main       -> FETCH_HEAD
# fatal: refusing to merge unrelated histories

# %%
# !git commit
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add Linear_Regression

# %%
# !git commit -m "Structured Linear Regression Folder"
# Out:
# [main ff3dc49] Structured Linear Regression Folder
#  1 file changed, 1 deletion(-)
#  delete mode 100644 Linear_Regression/Untitled

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push -u origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git push origin main
# Out:
# To https://github.com/ydv-prince/Machine-Learning.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/ydv-prince/Machine-Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main --allow-unrelated-histories --no-rebase
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git commit -m "Merge remote main into local main"
# Out:
# [main 147ffdc] Merge remote main into local main

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Decision_Tree/
# 	Logistic_Regression/
# 	Repo Folder fix.ipynb
# 	SVM & Naive Bayes/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push origin main
# Out:
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (15/15), 598.49 KiB | 2.88 MiB/s, done.
# Total 15 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 1 local object.
# To https://github.com/ydv-prince/Machine-Learning.git
#    d7df0a5..147ffdc  main -> main
